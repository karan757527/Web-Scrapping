# %%
import requests
import os
from bs4 import BeautifulSoup
import re
req=requests.get('https://www.sanfoundry.com/')
soup=BeautifulSoup(req.text)
all_links=soup.find('div',class_='entry-content').find_all('a')
d={}
for i in all_links:
    d[i.text]=i.get('href')
# 452 keys
# 1 to 10, 11 to 20,21 to 30
start=int(input('From Key:'))
stop=int(input('To Key:'))
sid=int(input('Folder Number:'))
print(f'Scrapping from {start} to {stop}.')
stop+=1
key=start
for x,subject in enumerate(list(d.keys())[start:stop]):
    if re.match('1000.*?MCQs',subject):
        name_sub="_".join(subject.split()[1:-1])
        link_sub=d[subject]
        r_sub=requests.get(link_sub)
        soup_sub=BeautifulSoup(r_sub.text)
        sub=soup_sub.find('div',class_='entry-content')
        print('-------------------------------------------------------------------------------------------')
        print(f'--> Subject Key -->',key)
        print(f'--> Writing -->',subject)
        print('-------------------------------------------------------------------------------------------')
        for topic,table in zip(sub.find_all('h4'),sub.find_all('table')):
            print('\t---------------------------------------------------------------------------------------')
            print("\t--> Writing -->",topic.text)
            print('\t---------------------------------------------------------------------------------------')
            t_name='-'.join(re.split(';|,|\*|\n|/|\\|\.|:','_'.join(topic.text.split())))
            try:
                os.makedirs(f"SF\\{sid}. {name_sub}\\{t_name}\\Questions")
                os.makedirs(f"SF\\{sid}. {name_sub}\\{t_name}\\Answers")
            except OSError:
                pass
            for st in table.find_all('a'):
                questions="----Project By Karan Agrawal & Chirag Agarwal----\n\n\n"
                answers="----Project By Karan Agrawal & Chirag Agarwal----\n\n\n"
                sub_topic=st.text
                print("\t\t--> Writing -->",sub_topic)
                req_st=requests.get(st.get('href'))
                soup_st=BeautifulSoup(req_st.text)
                for que in soup_st.find('div',class_='entry-content').find_all('p')[1:-3]:
                    questions+="\n"+que.text.split('View Answer')[0]+"\n"
                    if que.find_next_sibling() and que.find_next_sibling().name=='pre':
                        questions+=que.find_next_sibling().text+'\n'
                    if que.find('img') and que.find('img').get('src'):
                        questions+=que.find('img').get('src')+'\n'
                    if que.find_next_sibling() and que.find_next_sibling().get('class'):
                        if que.find_next_sibling().get('class')[0]=='hk1_style-wrap5' :
                            for li in que.find_next_sibling().find_all('li'):
                                questions+=li.text+'\n'
                        elif que.find_next_sibling().get('class')[0]=="sf-mobile-ads" :
                            for li in que.find_next_sibling().find_next_sibling().find_all('li'):
                                questions+=li.text+'\n'
                for ans in soup_st.find('div',class_='entry-content').find_all('div',class_='collapseomatic_content'):
                    answers+="\n"+ans.text+"\n"
                f_name='-'.join(re.split(';|,|\*|\n|/|\\|\.|:',('_'.join(sub_topic.split()))))
                try:
                    with open(f"SF\\{sid}. {name_sub}\\{t_name}\\Questions\\{f_name}.txt",'w',encoding='utf-8') as fp:
                        questions+="\n\n----Project By Karan Agrawal and Chirag Agarwal----\n"
                        fp.write(questions)
                    with open(f"SF\\{sid}. {name_sub}\\{t_name}\\Answers\\{f_name}.txt",'w',encoding='utf-8') as fp:
                        answers+="\n\n----Project By Karan Agrawal and Chirag Agarwal----\n"
                        fp.write(answers)
                except FileNotFoundError:
                    print('File Not Found Error Handled')
        sid+=1
    key+=1
        
    print('-------------------------------------------------------------------------------------------')
# Out:
# From Key:300
# To Key:414
# Folder Number:138
# Scrapping from 300 to 414.
# -------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------
# ...

# %%
import requests
import os
from bs4 import BeautifulSoup
import re
req=requests.get('https://www.sanfoundry.com/')
soup=BeautifulSoup(req.text)
all_links=soup.find('div',class_='entry-content').find_all('a')
d={}
for i in all_links:
    d[i.text]=i.get('href')
x=list(d.keys())
y={}
j=0
for i,subject in enumerate(x):
    if re.match('1000.*?MCQs',subject):
        j+=1
        name=str(j)+". "+"_".join(subject.split()[1:-1])
        y[i]=name

# %%
y
# Out:
# {5: '1. Data_Structures_&_Algorithms_I',
#  6: '2. Data_Structures_&_Algorithms_II',
#  7: '3. Python',
#  8: '4. Java',
#  9: '5. C++',
#  10: '6. C',
#  11: '7. C#',
#  39: '8. Object_Oriented_Programming',
#  41: '9. Linux',
#  44: '10. JUnit',
#  45: '11. JavaScript',
#  47: '12. Spring',
#  49: '13. SAN',
#  50: '14. PHP',
#  53: '15. Ruby',
#  54: '16. Hadoop',
#  56: '17. R_Programming',
#  58: '18. Cloud_Computing',
#  60: '19. Data_Science',
#  62: '20. MongoDB',
#  64: '21. SQL_Server',
#  66: '22. MySQL',
#  68: '23. Oracle',
#  69: '24. HTML',
#  70: '25. CSS',
#  71: '26. IOT',
#  73: '27. Unix',
#  75: '28. Computer_Fundamentals',
#  77: '29. Cyber_Security',
#  79: '30. Operating_System',
#  81: '31. Computer_Architecture',
#  83: '32. Software_Engineering',
#  85: '33. Software_Architecture',
#  87: '34. Artificial_Intelligence',
#  89: '35. LISP_Programming',
#  90: '36. Computer_Network',
#  92: '37. Cryptograph_&_Network_Security',
#  93: '38. Microprocessor',
# ...

# %%
# !ls
# Out:
# Assignments
# Material
# Practice
# SF
# SF-Copy1.ipynb
# SF.ipynb
# Whatsapp Notebooks

# %%
# !cd SF

# %%
# !cat "SF/251251. Machine_Drawing/1._Questions_&_Answers_on_Drawing_Fundamentals/Questions/Method_of_Expression.txt
# Out:
# ----Project By Karan Agrawal & Chirag Agarwal----
#
#
#
# 1. Axonometric view is a type of _____________
# a) Orthographic view
# b) Pictorial view
# c) Oblique View
# d) Pictorial and Oblique View
#
#
# 2. In an axonometric view, line of site are   ______________
# a) Perpendicular to plane of projection with all three faces equally inclined to picture plane
# b) Perpendicular to plane of projection with all three faces need not be equally inclined to picture plane
# c) Inclined to the plane of projection at certain angle
# d) One face of the object needs to be parallel
#
#
# 3. The figure shown below depicts which type of view?
#
# a) Oblique View
# b) Perspective View
# c) Axonometric View
# d) Orthographic View
#
# https://www.sanfoundry.com/wp-content/uploads/2017/11/machine-drawing-questions-answers-method-expression-q3-300x229.png
#
# 4. Which type of view is shown in the below figure?
#
# a) Oblique View
# b) Perspective View
# c) Axonometric View
# d) Orthographic View
#
# ...

# %% [markdown]
#      5: '1. Data_Structures_&_Algorithms_I',
#      6: '2. Data_Structures_&_Algorithms_II',
#      7: '3. Python',
#      8: '4. Java',
#      9: '5. C++',
#      10: '6. C',
#      11: '7. C#',
#      39: '8. Object_Oriented_Programming',
#      41: '9. Linux',
#      44: '10. JUnit',
#      45: '11. JavaScript',
#      47: '12. Spring',
#      49: '13. SAN',
#      50: '14. PHP',
#      53: '15. Ruby',
#      54: '16. Hadoop',
#      56: '17. R_Programming',
#      58: '18. Cloud_Computing',
#      60: '19. Data_Science',
#      62: '20. MongoDB',
#      64: '21. SQL_Server',
#      66: '22. MySQL',
#      68: '23. Oracle',
#      69: '24. HTML',
#      70: '25. CSS',
#      71: '26. IOT',
#      73: '27. Unix',
#      75: '28. Computer_Fundamentals',
#      77: '29. Cyber_Security',
#      79: '30. Operating_System',
#      81: '31. Computer_Architecture',
#      83: '32. Software_Engineering',
#      85: '33. Software_Architecture',
#      87: '34. Artificial_Intelligence',
#      89: '35. LISP_Programming',
#      90: '36. Computer_Network',
#      92: '37. Cryptograph_&_Network_Security',
#      93: '38. Microprocessor',
#      95: '39. Microcontroller',
#      97: '40. Computer_Graphics',
#      98: '41. Database_Management',
#      100: '42. RDBMS',
#      101: '43. Discrete_Mathematics',
#      103: '44. Compiler',
#      104: '45. Embedded_Systems',
#      106: '46. Automata_Theory',
#      108: '47. Engineering_Mathematics',
#      109: '48. Probability_and_Statistics',
#      110: '49. Numerical_Methods',
#      111: '50. Engineering_Physics_I',
#      113: '51. Engineering_Physics_II',
#      115: '52. Engineering_Chemistry_I',
#      117: '53. Engineering_Chemistry_II',
#      119: '54. Engineering_Mechanics',
#      121: '55. Engineering_Drawing',
#      123: '56. Professional_Communication',
#      125: '57. Basic_Electrical_Engineering',
#      127: '58. Basic_Chemical_Engineering',
#      129: '59. Basic_Civil_Engineering',
#      131: '60. Applied_Chemistry',
#      133: '61. Heat_Transfer',
#      135: '62. Mass_Transfer',
#      137: '63. Heat_Transfer_Operations',
#      139: '64. Polymer_Engineering',
#      140: '65. Unit_Processes',
#      141: '66. Separation_Processes',
#      142: '67. Mechanical_Operations',
#      143: '68. Distillation_Design',
#      144: '69. Pulp_&_Paper',
#      145: '70. Food_Engineering',
#      147: '71. Thermodynamics',
#      148: '72. Chemical_Process_Calculation',
#      149: '73. Organic_Chemistry',
#      151: '74. Materials_Science',
#      153: '75. Fluidization_Engineering',
#      154: '76. Civil_Engineering_Drawing',
#      155: '77. Fermentation_Technology',
#      157: '78. Computational_Fluid_Dynamics',
#      197: '79. Electric_Circuits',
#      198: '80. Electric_Drives',
#      200: '81. Digital_Signal_Processing',
#      202: '82. Digital_Communications',
#      204: '83. Linear_Integrated_Circuits',
#      205: '84. Digital_Image_Processing',
#      206: '85. Electrical_Machines',
#      207: '86. Design_of_Electrical_Machines',
#      208: '87. Electromagnetic_Theory',
#      209: '88. Power_Systems',
#      210: '89. Power_Electronics',
#      211: '90. Network_Theory',
#      212: '91. Signals_and_Systems',
#      213: '92. VLSI',
#      214: '93. Control_Systems',
#      215: '94. Microwave_Engineering',
#      216: '95. Digital_Circuits',
#      217: '96. Analog_Circuits',
#      218: '97. Electronic_Devices_&_Circuits',
#      219: '98. Neural_Networks',
#      220: '99. Optical_Communications',
#      221: '100. Electrical_Measurements',
#      222: '101. DC_Machines',
#      223: '102. Transformers',
#      224: '103. Analog_Communications',
#      225: '104. Biomedical_Instrumentation',
#      227: '105. Wireless/Mobile',
#      228: '106. VHDL',
#      230: '107. MATLAB',
#      232: '108. Dairy_Engineering',
#      234: '109. Strength_of_Materials',
#      236: '110. Theory_of_Machines',
#      237: '111. Irrigation_Engineering',
#      239: '112. Avionics',
#      241: '113. Aerodynamics',
#      242: '114. Aircraft_Design',
#      244: '115. Aircraft_Maintenance',
#      246: '116. Rocket_Propulsion',
#      247: '117. Aerospace_Materials_&_Processes',
#      248: '118. Fluid_Mechanics',
#      249: '119. Hydraulic_Machines',
#      250: '120. Machine_Design',
#      251: '121. Machine_Drawing',
#      252: '122. Machine_Dynamics',
#      253: '123. Machine_Kinematics',
#      254: '124. Manufacturing_Engineering_I',
#      256: '125. Manufacturing_Engineering_II',
#      258: '126. GeoTechnical_Engineering',
#      260: '127. Engineering_Geology',
#      262: '128. Environmental_Engineering',
#      264: '129. Highway_Engineering',
#      266: '130. Structural_Analysis',
#      267: '131. Construction_&_Building_Materials',
#      269: '132. Concrete_Technology',
#      271: '133. Prestressed_Concrete_Structures',
#      273: '134. Design_of_Steel_Structures',
#      274: '135. Hazardous_Waste_Management',
#      276: '136. Waste_Water_Engineering',
#      278: '137. Surveying',
#      362: '138. Casting-Forming-Welding_I',
#      364: '139. Casting-Forming-Welding_II',
#      366: '140. Machine_Tools',
#      367: '141. Advanced_Machining',
#      368: '142. IC_Engine',
#      369: '143. Power_Plant_Engineering',
#      370: '144. Steam_and_Gas_Turbines',
#      371: '145. Automobile_Engineering',
#      372: '146. Energy_Engineering',
#      374: '147. Energy_Management',
#      376: '148. Statistical_Quality_Control',
#      378: '149. Engineering_Metrology',
#      380: '150. Foundry_and_Forging',
#      381: '151. Engineering_Material_&_Metallurgy',
#      383: '152. Mechanical_Behaviour',
#      385: '153. Testing_of_Materials',
#      387: '154. Genetic_Engineering',
#      389: '155. Biochemistry',
#      391: '156. Bioinformatics',
#      392: '157. Bioprocess_Engineering',
#      393: '158. Molecular_Biology',
#      395: '159. Microbiology',
#      397: '160. Cytogenetics',
#      399: '161. Clinical_Science',
#      401: '162. Vector_Biology',
#      403: '163. Life_Sciences',
#      405: '164. Solid_State_Chemistry',
#      406: '165. Human_Anatomy_and_Physiology',
#      408: '166. Drug_Biotechnology',
#      410: '167. Cell_Biology',
#      412: '168. Analytical_Instrumentation',
#      414: '169. Instrumentation_Transducers'
